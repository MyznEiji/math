# %%
import random
import numpy as np
import matplotlib.pyplot as plt


# how_many_times = np.arange(1, 2000, 10)
# how_many_times = np.arange(1000, 100000, 1000)
# how_many_times = np.arange(1000, 10000, 1000)
# how_many_times = np.arange(100000, 1000000, 100000)
how_many_times = np.array([10, 100, 500, 1000, 5000, 10000])
your_choice = int(input("[0, 1, 2] どの数字を選択しますか?"))
print("-------------------------------------")
change_list = []
no_change_list = []


for num in how_many_times:
    hoge = "*"

    for _ in range(num):
        hoge = hoge + "*"
        print(hoge)





# for num in how_many_times:
#     for _ in range(10):

#         correct_num = 0
#         changing_correct_num = 0
#         no_change_sum = 0
#         change_sum = 0
#         for _ in range(num):


#             answer_num = random.randint(0,2)
#             if answer_num == your_choice:
#                 correct_num += 1
#             else:
#                 changing_correct_num += 1

#         no_change_average = (correct_num / num)*100
#         change_average = (changing_correct_num / num)*100
        
#         no_change_sum += no_change_average
#         change_sum += change_average
        

        
        
#     change_list.append(change_sum / 10)
#     no_change_list.append(no_change_sum / 10)
    
#     print(change_list)
#     print(no_change_list)
    
#     print(num)
#     print("no_change : ", no_change_average)
#     print("change : ",  change_average)
#     print("-------------------------------------")



# plt.plot(how_many_times, change_list, label="change")
# plt.plot(how_many_times, no_change_list, label="no_change")
# # plt.ylim([66.5, 67])
# plt.ylim([55, 80])
# plt.show()
# Out:
# [0, 1, 2] どの数字を選択しますか?0
# -------------------------------------
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# ************
# *************
# **************
# ***************
# ****************
# *****************
# ******************
# *******************
# ********************
# *********************
# **********************
# ***********************
# ************************
# *************************
# **************************
# ***************************
# ****************************
# *****************************
# ******************************
# *******************************
# ********************************
# *********************************
# **********************************
# ***********************************
# ************************************
# *************************************
# ...
